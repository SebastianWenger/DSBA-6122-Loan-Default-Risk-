# %%
import pandas as pd
import numpy as np
import gc

from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score

import lightgbm as lgb

# %% [markdown]
# ## Set random number seed, read in main table (to join target variable to loan ID), and feature matrix created in preprocessing notebook.

# %%
seed=123
X=pd.read_pickle('loan data.pkl')
Y=X.join(pd.read_csv("application_train.csv")[['SK_ID_CURR','TARGET']].set_index('SK_ID_CURR').TARGET,how='left').TARGET

# %% [markdown]
# ## We want to create dummy variables for all categorical variables (shown below), but only if their category number is >2.

# %%
X.select_dtypes(include=['object']).columns
# Out:
# Index(['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'NAME_TYPE_SUITE',
#        'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',
#        'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START',
#        'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE',
#        'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY'],
#       dtype='object')

# %% [markdown]
# ## The below will create dummy variables for categories >2, and will convert any text (male, female) to 0,1 if there are only 2 categories

# %%
categcolumns=[]

for col in X.select_dtypes(include=['object']).columns:
    if X[col].nunique()==2:
        X[col], _ = pd.factorize(X[col])
    elif X[col].nunique()>2:
        categcolumns.append(col)

dummies=pd.get_dummies(X[categcolumns])
X=pd.concat([X.drop(categcolumns,axis=1), dummies], axis=1)

# %%
X=X[X.count().sort_values(ascending=False).index]

# %% [markdown]
# ## Same process of dropping correlated columns in preprocessing notebook, except now on all of the final aggregated features with the main table features

# %%
corr_matrix = X.corr().abs()

# %%
threshold = 0.95
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

print('There are %d columns to remove.' % (len(to_drop)))
# Out:
# There are 2178 columns to remove.

# %%
to_drop
# Out:
# ['SUM(CREDIT_CARD_BALANCE.SK_DPD_DEF/CNT_DRAWINGS_POS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE/AMT_RECIVABLE)',
#  'SUM(CREDIT_CARD_BALANCE.SK_DPD_DEF/AMT_BALANCE)',
#  'SUM(CREDIT_CARD_BALANCE.SK_DPD_DEF/AMT_DRAWINGS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE/SK_DPD)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE-AMT_RECIVABLE)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/AMT_RECIVABLE)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/AMT_RECEIVABLE_PRINCIPAL)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_INST_MIN_REGULARITY)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/AMT_INST_MIN_REGULARITY)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE/AMT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE/CNT_DRAWINGS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE/CNT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE/CNT_DRAWINGS_POS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/CNT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.SK_ID_PREV)',
#  'SUM(CREDIT_CARD_BALANCE.SK_DPD_DEF)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL)',
#  'SUM(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.MONTHS_BALANCE)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY)',
#  'SUM(BUREAU.AMT_CREDIT_SUM_DEBT/AMT_CREDIT_SUM_LIMIT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*CNT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*CNT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(BUREAU.CNT_CREDIT_PROLONG/AMT_CREDIT_MAX_OVERDUE)',
#  'SUM(CREDIT_CARD_BALANCE.MONTHS_BALANCE/CNT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.MONTHS_BALANCE/AMT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY*CNT_INSTALMENT_MATURE_CUM)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY/CNT_INSTALMENT_MATURE_CUM)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY/CNT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY+AMT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY-AMT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY*CNT_DRAWINGS_POS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.MONTHS_BALANCE-CNT_INSTALMENT_MATURE_CUM)',
#  'SUM(CREDIT_CARD_BALANCE.MONTHS_BALANCE*AMT_INST_MIN_REGULARITY)',
#  'SUM(CREDIT_CARD_BALANCE.MONTHS_BALANCE/AMT_INST_MIN_REGULARITY)',
#  'SUM(CREDIT_CARD_BALANCE.MONTHS_BALANCE*CNT_INSTALMENT_MATURE_CUM)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY/CNT_DRAWINGS_POS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_POS_CURRENT-AMT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.CNT_INSTALMENT_MATURE_CUM/CNT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.CNT_INSTALMENT_MATURE_CUM/AMT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.CNT_INSTALMENT_MATURE_CUM/AMT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.CNT_DRAWINGS_ATM_CURRENT*CNT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.CNT_DRAWINGS_ATM_CURRENT*AMT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT/AMT_INST_MIN_REGULARITY)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*CNT_DRAWINGS_POS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT-AMT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/SK_DPD)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/AMT_RECIVABLE)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/AMT_RECEIVABLE_PRINCIPAL)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/MONTHS_BALANCE)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*CNT_DRAWINGS_POS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/CNT_DRAWINGS_POS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/AMT_PAYMENT_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT/AMT_PAYMENT_TOTAL_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT+AMT_PAYMENT_TOTAL_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT/SK_DPD)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT/AMT_RECEIVABLE_PRINCIPAL)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*CNT_DRAWINGS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT/CNT_DRAWINGS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*MONTHS_BALANCE)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*MONTHS_BALANCE)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'SUM(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'SUM(CREDIT_CARD_BALANCE.SK_DPD/AMT_RECIVABLE)',
#  'SUM(CREDIT_CARD_BALANCE.SK_DPD*MONTHS_BALANCE)',
#  'SUM(CREDIT_CARD_BALANCE.SK_DPD/MONTHS_BALANCE)',
#  'SUM(CREDIT_CARD_BALANCE.SK_DPD/AMT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.SK_DPD/AMT_RECEIVABLE_PRINCIPAL)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/AMT_INST_MIN_REGULARITY)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/AMT_PAYMENT_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/CNT_INSTALMENT_MATURE_CUM)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*CNT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT+AMT_DRAWINGS_POS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*AMT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/AMT_DRAWINGS_OTHER_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/CNT_DRAWINGS_POS_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT+AMT_DRAWINGS_ATM_CURRENT)',
#  'SUM(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*AMT_PAYMENT_CURRENT)',
#  'SUM(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY)',
#  'SUM(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START)',
#  'SUM(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*DAYS_DECISION)',
#  'SUM(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT/DAYS_ENTRY_PAYMENT)',
#  'SUM(PREVIOUS_APPLICATION.SELLERPLACE_AREA+AMT_ANNUITY)',
#  'SUM(PREVIOUS_APPLICATION.AMT_APPLICATION/AMT_ANNUITY)',
#  'SUM(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/CNT_PAYMENT)',
#  'SUM(PREVIOUS_APPLICATION.AMT_APPLICATION/AMT_GOODS_PRICE)',
#  'SUM(PREVIOUS_APPLICATION.AMT_ANNUITY/AMT_GOODS_PRICE)',
#  'SUM(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*NFLAG_INSURED_ON_APPROVAL)',
#  'SUM(PREVIOUS_APPLICATION.AMT_APPLICATION*AMT_CREDIT)',
#  'SUM(PREVIOUS_APPLICATION.SELLERPLACE_AREA-AMT_ANNUITY)',
#  'SUM(PREVIOUS_APPLICATION.DAYS_DECISION*AMT_CREDIT)',
#  'SUM(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/AMT_CREDIT)',
#  'SUM(PREVIOUS_APPLICATION.AMT_APPLICATION/AMT_CREDIT)',
#  'SUM(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*AMT_ANNUITY)',
#  'SUM(PREVIOUS_APPLICATION.CNT_PAYMENT*AMT_ANNUITY)',
#  'SUM(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*CNT_PAYMENT)',
#  'SUM(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/AMT_ANNUITY)',
#  'SUM(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT*DAYS_INSTALMENT)',
#  'REGION_RATING_CLIENT_W_CITY',
#  'SUM(INSTALLMENTS_PAYMENTS.NUM_INSTALMENT_NUMBER)',
#  'SUM(POS_CASH_BALANCE.MONTHS_BALANCE/CNT_INSTALMENT_FUTURE)',
#  'SUM(INSTALLMENTS_PAYMENTS.SK_ID_PREV)',
#  'SUM(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT)',
#  'SUM(POS_CASH_BALANCE.MONTHS_BALANCE*CNT_INSTALMENT_FUTURE)',
#  'SUM(POS_CASH_BALANCE.SK_ID_PREV)',
#  'SUM(POS_CASH_BALANCE.MONTHS_BALANCE)',
#  'SUM(POS_CASH_BALANCE.CNT_INSTALMENT)',
#  'SUM(POS_CASH_BALANCE.SK_DPD_DEF*MONTHS_BALANCE)',
#  'SUM(POS_CASH_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'SUM(POS_CASH_BALANCE.SK_DPD*MONTHS_BALANCE)',
#  'SUM(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT+RATE_INTEREST_PRIVILEGED)',
#  'SUM(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT-RATE_INTEREST_PRIVILEGED)',
#  'SUM(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*RATE_INTEREST_PRIMARY)',
#  'SUM(PREVIOUS_APPLICATION.RATE_INTEREST_PRIVILEGED+RATE_INTEREST_PRIMARY)',
#  'SUM(PREVIOUS_APPLICATION.CNT_PAYMENT*RATE_INTEREST_PRIVILEGED)',
#  'SUM(PREVIOUS_APPLICATION.CNT_PAYMENT/RATE_INTEREST_PRIVILEGED)',
#  'SUM(PREVIOUS_APPLICATION.CNT_PAYMENT/RATE_INTEREST_PRIMARY)',
#  'SUM(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/RATE_INTEREST_PRIMARY)',
#  'SUM(PREVIOUS_APPLICATION.RATE_INTEREST_PRIVILEGED-RATE_INTEREST_PRIMARY)',
#  'SUM(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/RATE_INTEREST_PRIVILEGED)',
#  'SUM(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*RATE_INTEREST_PRIVILEGED)',
#  'SUM(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL+RATE_INTEREST_PRIVILEGED)',
#  'SUM(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL-RATE_INTEREST_PRIVILEGED)',
#  'SUM(BUREAU.DAYS_CREDIT_UPDATE/CREDIT_DAY_OVERDUE)',
#  'SUM(BUREAU.DAYS_CREDIT_UPDATE+DAYS_CREDIT)',
#  'SUM(BUREAU.AMT_CREDIT_SUM_OVERDUE/AMT_CREDIT_SUM_LIMIT)',
#  'SUM(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM_LIMIT)',
#  'SUM(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT+RATE_INTEREST_PRIMARY)',
#  'SUM(PREVIOUS_APPLICATION.AMT_CREDIT*DAYS_LAST_DUE)',
#  'SUM(PREVIOUS_APPLICATION.CNT_PAYMENT*DAYS_LAST_DUE)',
#  'SUM(PREVIOUS_APPLICATION.RATE_INTEREST_PRIVILEGED/RATE_INTEREST_PRIMARY)',
#  'SUM(PREVIOUS_APPLICATION.RATE_INTEREST_PRIVILEGED*RATE_INTEREST_PRIMARY)',
#  'SUM(PREVIOUS_APPLICATION.CNT_PAYMENT/AMT_DOWN_PAYMENT)',
#  'SUM(BUREAU.MEDIAN(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'SUM(BUREAU.MEAN(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'COUNT(BUREAU_BALANCE)',
#  'SUM(BUREAU.STD(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'NAME_INCOME_TYPE_Pensioner',
#  'AMT_GOODS_PRICE',
#  'OBS_60_CNT_SOCIAL_CIRCLE',
#  'MEAN(INSTALLMENTS_PAYMENTS.DAYS_INSTALMENT*NUM_INSTALMENT_NUMBER)',
#  'MEAN(INSTALLMENTS_PAYMENTS.DAYS_INSTALMENT/NUM_INSTALMENT_NUMBER)',
#  'MEAN(INSTALLMENTS_PAYMENTS.NUM_INSTALMENT_NUMBER)',
#  'MEAN(INSTALLMENTS_PAYMENTS.DAYS_INSTALMENT)',
#  'MAX(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT/DAYS_INSTALMENT)',
#  'MIN(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT*NUM_INSTALMENT_VERSION)',
#  'MIN(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT*NUM_INSTALMENT_NUMBER)',
#  'MIN(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT/NUM_INSTALMENT_NUMBER)',
#  'MAX(INSTALLMENTS_PAYMENTS.DAYS_INSTALMENT*NUM_INSTALMENT_VERSION)',
#  'MEAN(INSTALLMENTS_PAYMENTS.AMT_PAYMENT)',
#  'MAX(INSTALLMENTS_PAYMENTS.AMT_PAYMENT)',
#  'MAX(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT/DAYS_ENTRY_PAYMENT)',
#  'MAX(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT*AMT_PAYMENT)',
#  'MIN(INSTALLMENTS_PAYMENTS.DAYS_INSTALMENT*AMT_PAYMENT)',
#  'MEDIAN(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT*AMT_PAYMENT)',
#  'MEDIAN(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT/DAYS_ENTRY_PAYMENT)',
#  'MEDIAN(INSTALLMENTS_PAYMENTS.DAYS_INSTALMENT*AMT_PAYMENT)',
#  'MEAN(INSTALLMENTS_PAYMENTS.DAYS_INSTALMENT*AMT_PAYMENT)',
#  'MEDIAN(INSTALLMENTS_PAYMENTS.AMT_PAYMENT)',
#  'MEAN(INSTALLMENTS_PAYMENTS.NUM_INSTALMENT_NUMBER/AMT_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.DAYS_DECISION)',
#  'MEAN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/AMT_CREDIT)',
#  'MEAN(PREVIOUS_APPLICATION.DAYS_DECISION*AMT_CREDIT)',
#  'MEAN(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/AMT_CREDIT)',
#  'MEDIAN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START)',
#  'MEDIAN(PREVIOUS_APPLICATION.DAYS_DECISION)',
#  'MEDIAN(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/HOUR_APPR_PROCESS_START)',
#  'MEDIAN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*DAYS_DECISION)',
#  'MIN(PREVIOUS_APPLICATION.AMT_APPLICATION*DAYS_DECISION)',
#  'PREVIOUS_APPLICATION.NAME_PORTFOLIO_Cars',
#  'MAX(PREVIOUS_APPLICATION.SELLERPLACE_AREA)',
#  'PREVIOUS_APPLICATION.FLAG_LAST_APPL_PER_CONTRACT_Y',
#  'STD(INSTALLMENTS_PAYMENTS.NUM_INSTALMENT_NUMBER)',
#  'STD(INSTALLMENTS_PAYMENTS.NUM_INSTALMENT_NUMBER*NUM_INSTALMENT_VERSION)',
#  'STD(INSTALLMENTS_PAYMENTS.DAYS_INSTALMENT*AMT_PAYMENT)',
#  'STD(INSTALLMENTS_PAYMENTS.AMT_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.SELLERPLACE_AREA+AMT_ANNUITY)',
#  'MEDIAN(PREVIOUS_APPLICATION.SELLERPLACE_AREA-AMT_ANNUITY)',
#  'MAX(PREVIOUS_APPLICATION.CNT_PAYMENT*AMT_ANNUITY)',
#  'MEAN(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/CNT_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.DAYS_DECISION*AMT_ANNUITY)',
#  'MEAN(PREVIOUS_APPLICATION.DAYS_DECISION/CNT_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.AMT_ANNUITY)',
#  'MEAN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/CNT_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*AMT_ANNUITY)',
#  'MAX(PREVIOUS_APPLICATION.SELLERPLACE_AREA/AMT_ANNUITY)',
#  'MIN(PREVIOUS_APPLICATION.AMT_ANNUITY)',
#  'SKEW(INSTALLMENTS_PAYMENTS.DAYS_INSTALMENT*AMT_PAYMENT)',
#  'SKEW(INSTALLMENTS_PAYMENTS.AMT_PAYMENT)',
#  'SKEW(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT/DAYS_ENTRY_PAYMENT)',
#  'SKEW(INSTALLMENTS_PAYMENTS.AMT_INSTALMENT*AMT_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.AMT_APPLICATION/AMT_GOODS_PRICE)',
#  'MAX(PREVIOUS_APPLICATION.AMT_APPLICATION/AMT_GOODS_PRICE)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_APPLICATION/AMT_GOODS_PRICE)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_ANNUITY/AMT_GOODS_PRICE)',
#  'MEAN(PREVIOUS_APPLICATION.CNT_PAYMENT/AMT_GOODS_PRICE)',
#  'MEAN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*NFLAG_INSURED_ON_APPROVAL)',
#  'MAX(PREVIOUS_APPLICATION.SELLERPLACE_AREA*NFLAG_INSURED_ON_APPROVAL)',
#  'MEDIAN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*NFLAG_INSURED_ON_APPROVAL)',
#  'MIN(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL)',
#  'MEDIAN(PREVIOUS_APPLICATION.SELLERPLACE_AREA/DAYS_FIRST_DUE)',
#  'MEAN(PREVIOUS_APPLICATION.SELLERPLACE_AREA/DAYS_FIRST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.AMT_APPLICATION/DAYS_FIRST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/DAYS_FIRST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.AMT_ANNUITY/DAYS_FIRST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.CNT_PAYMENT/DAYS_FIRST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/DAYS_FIRST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.SELLERPLACE_AREA/DAYS_FIRST_DUE)',
#  'MEDIAN(POS_CASH_BALANCE.SK_DPD_DEF)',
#  'MEAN(POS_CASH_BALANCE.SK_DPD_DEF-MONTHS_BALANCE)',
#  'MEAN(POS_CASH_BALANCE.SK_DPD*MONTHS_BALANCE)',
#  'MEAN(POS_CASH_BALANCE.SK_DPD/MONTHS_BALANCE)',
#  'MEDIAN(POS_CASH_BALANCE.SK_DPD)',
#  'MEAN(POS_CASH_BALANCE.SK_DPD_DEF*MONTHS_BALANCE)',
#  'MEDIAN(POS_CASH_BALANCE.SK_DPD_DEF*MONTHS_BALANCE)',
#  'MEDIAN(POS_CASH_BALANCE.SK_DPD_DEF+MONTHS_BALANCE)',
#  'MEDIAN(POS_CASH_BALANCE.SK_DPD*MONTHS_BALANCE)',
#  'MEDIAN(POS_CASH_BALANCE.SK_DPD/MONTHS_BALANCE)',
#  'MEDIAN(POS_CASH_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'MEAN(POS_CASH_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'MAX(POS_CASH_BALANCE.SK_DPD_DEF-MONTHS_BALANCE)',
#  'MEAN(POS_CASH_BALANCE.SK_DPD)',
#  'MEAN(POS_CASH_BALANCE.SK_DPD_DEF)',
#  'MIN(POS_CASH_BALANCE.SK_DPD_DEF)',
#  'MIN(POS_CASH_BALANCE.SK_DPD)',
#  'MIN(POS_CASH_BALANCE.MONTHS_BALANCE)',
#  'MIN(POS_CASH_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'MIN(POS_CASH_BALANCE.SK_DPD_DEF+MONTHS_BALANCE)',
#  'MAX(POS_CASH_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'MAX(POS_CASH_BALANCE.SK_DPD_DEF)',
#  'MAX(POS_CASH_BALANCE.MONTHS_BALANCE)',
#  'MEDIAN(POS_CASH_BALANCE.SK_DPD/CNT_INSTALMENT)',
#  'MEDIAN(POS_CASH_BALANCE.SK_DPD*CNT_INSTALMENT)',
#  'MEAN(POS_CASH_BALANCE.CNT_INSTALMENT_FUTURE)',
#  'MEAN(POS_CASH_BALANCE.MONTHS_BALANCE-CNT_INSTALMENT)',
#  'MEAN(POS_CASH_BALANCE.MONTHS_BALANCE*CNT_INSTALMENT)',
#  'MEAN(POS_CASH_BALANCE.MONTHS_BALANCE/CNT_INSTALMENT_FUTURE)',
#  'MEAN(POS_CASH_BALANCE.SK_DPD*CNT_INSTALMENT)',
#  'MEAN(POS_CASH_BALANCE.SK_DPD/CNT_INSTALMENT)',
#  'MEAN(POS_CASH_BALANCE.CNT_INSTALMENT_FUTURE*CNT_INSTALMENT)',
#  'MEAN(POS_CASH_BALANCE.CNT_INSTALMENT_FUTURE-CNT_INSTALMENT)',
#  'MEDIAN(POS_CASH_BALANCE.MONTHS_BALANCE*CNT_INSTALMENT_FUTURE)',
#  'MIN(POS_CASH_BALANCE.MONTHS_BALANCE+CNT_INSTALMENT)',
#  'MIN(POS_CASH_BALANCE.MONTHS_BALANCE-CNT_INSTALMENT)',
#  'MAX(POS_CASH_BALANCE.CNT_INSTALMENT)',
#  'MAX(POS_CASH_BALANCE.CNT_INSTALMENT_FUTURE*CNT_INSTALMENT)',
#  'MAX(POS_CASH_BALANCE.CNT_INSTALMENT_FUTURE-CNT_INSTALMENT)',
#  'MIN(POS_CASH_BALANCE.SK_DPD/CNT_INSTALMENT)',
#  'MIN(POS_CASH_BALANCE.SK_DPD*CNT_INSTALMENT)',
#  'MIN(POS_CASH_BALANCE.MONTHS_BALANCE/CNT_INSTALMENT_FUTURE)',
#  'MIN(POS_CASH_BALANCE.MONTHS_BALANCE*CNT_INSTALMENT)',
#  'STD(POS_CASH_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'STD(POS_CASH_BALANCE.SK_DPD_DEF+MONTHS_BALANCE)',
#  'STD(POS_CASH_BALANCE.SK_DPD)',
#  'STD(POS_CASH_BALANCE.SK_DPD_DEF*MONTHS_BALANCE)',
#  'STD(POS_CASH_BALANCE.SK_DPD/MONTHS_BALANCE)',
#  'STD(POS_CASH_BALANCE.SK_DPD*MONTHS_BALANCE)',
#  'STD(POS_CASH_BALANCE.SK_DPD_DEF)',
#  'STD(POS_CASH_BALANCE.MONTHS_BALANCE*CNT_INSTALMENT_FUTURE)',
#  'STD(POS_CASH_BALANCE.SK_DPD_DEF*CNT_INSTALMENT_FUTURE)',
#  'STD(POS_CASH_BALANCE.SK_DPD*CNT_INSTALMENT)',
#  'STD(POS_CASH_BALANCE.SK_DPD/CNT_INSTALMENT)',
#  'STD(POS_CASH_BALANCE.CNT_INSTALMENT_FUTURE*CNT_INSTALMENT)',
#  'STD(POS_CASH_BALANCE.CNT_INSTALMENT_FUTURE)',
#  'STD(POS_CASH_BALANCE.CNT_INSTALMENT_FUTURE-CNT_INSTALMENT)',
#  'STD(POS_CASH_BALANCE.SK_DPD*CNT_INSTALMENT_FUTURE)',
#  'MEAN(PREVIOUS_APPLICATION.SELLERPLACE_AREA/AMT_CREDIT)',
#  'SKEW(POS_CASH_BALANCE.SK_DPD)',
#  'SKEW(POS_CASH_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'SKEW(POS_CASH_BALANCE.SK_DPD_DEF)',
#  'SKEW(POS_CASH_BALANCE.MONTHS_BALANCE)',
#  'SKEW(POS_CASH_BALANCE.SK_DPD/MONTHS_BALANCE)',
#  'SKEW(POS_CASH_BALANCE.SK_DPD/CNT_INSTALMENT)',
#  'SKEW(POS_CASH_BALANCE.CNT_INSTALMENT_FUTURE)',
#  'SKEW(POS_CASH_BALANCE.SK_DPD*CNT_INSTALMENT)',
#  'MIN(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL*DAYS_LAST_DUE_1ST_VERSION)',
#  'MIN(PREVIOUS_APPLICATION.SELLERPLACE_AREA/DAYS_LAST_DUE_1ST_VERSION)',
#  'MEAN(PREVIOUS_APPLICATION.SELLERPLACE_AREA/DAYS_LAST_DUE_1ST_VERSION)',
#  'MEDIAN(PREVIOUS_APPLICATION.SELLERPLACE_AREA/DAYS_LAST_DUE_1ST_VERSION)',
#  'MEDIAN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/DAYS_LAST_DUE_1ST_VERSION)',
#  'MIN(PREVIOUS_APPLICATION.AMT_APPLICATION/DAYS_LAST_DUE_1ST_VERSION)',
#  'MIN(PREVIOUS_APPLICATION.DAYS_LAST_DUE_1ST_VERSION)',
#  'MAX(PREVIOUS_APPLICATION.SELLERPLACE_AREA/DAYS_LAST_DUE_1ST_VERSION)',
#  'MEDIAN(PREVIOUS_APPLICATION.DAYS_LAST_DUE_1ST_VERSION)',
#  'SKEW(POS_CASH_BALANCE.SK_DPD_DEF/CNT_INSTALMENT_FUTURE)',
#  'MEAN(PREVIOUS_APPLICATION.DAYS_DECISION*AMT_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.DAYS_DECISION/AMT_DOWN_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.DAYS_DECISION/AMT_DOWN_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.AMT_CREDIT*AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.DAYS_DECISION/AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT*AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_CREDIT/AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_CREDIT*AMT_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.AMT_CREDIT/RATE_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.DAYS_DECISION/RATE_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.AMT_CREDIT/AMT_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT*AMT_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.AMT_GOODS_PRICE*AMT_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.AMT_CREDIT/AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_CREDIT/RATE_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.SELLERPLACE_AREA*RATE_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.DAYS_DECISION/AMT_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.AMT_GOODS_PRICE*AMT_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.AMT_CREDIT/RATE_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.SELLERPLACE_AREA+AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_CREDIT*RATE_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.DAYS_DECISION*RATE_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.DAYS_DECISION/RATE_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.SELLERPLACE_AREA-AMT_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.DAYS_DECISION/RATE_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/AMT_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/AMT_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.AMT_ANNUITY/RATE_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.CNT_PAYMENT*RATE_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.CNT_PAYMENT*AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_ANNUITY*RATE_DOWN_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.AMT_ANNUITY*AMT_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.CNT_PAYMENT*AMT_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.AMT_ANNUITY-AMT_DOWN_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.AMT_ANNUITY/RATE_DOWN_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.AMT_ANNUITY-AMT_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.SELLERPLACE_AREA/AMT_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.CNT_PAYMENT/RATE_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.CNT_PAYMENT/AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.CNT_PAYMENT/AMT_DOWN_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.CNT_PAYMENT/RATE_DOWN_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.CNT_PAYMENT/AMT_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.CNT_PAYMENT/AMT_DOWN_PAYMENT)',
#  'SKEW(POS_CASH_BALANCE.SK_DPD/CNT_INSTALMENT_FUTURE)',
#  'MAX(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL*AMT_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL*RATE_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.DAYS_LAST_DUE_1ST_VERSION*AMT_DOWN_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.AMT_CREDIT*DAYS_LAST_DUE)',
#  'MEDIAN(PREVIOUS_APPLICATION.DAYS_FIRST_DUE/DAYS_LAST_DUE)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_APPLICATION*DAYS_LAST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/DAYS_LAST_DUE)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_CREDIT*DAYS_LAST_DUE)',
#  'MAX(PREVIOUS_APPLICATION.DAYS_FIRST_DUE/DAYS_LAST_DUE)',
#  'MEDIAN(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/DAYS_LAST_DUE)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_ANNUITY*DAYS_LAST_DUE)',
#  'MEDIAN(PREVIOUS_APPLICATION.CNT_PAYMENT*DAYS_LAST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.AMT_CREDIT/DAYS_LAST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.AMT_ANNUITY/DAYS_LAST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/DAYS_LAST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.AMT_APPLICATION*DAYS_LAST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.CNT_PAYMENT/DAYS_LAST_DUE)',
#  'MEAN(PREVIOUS_APPLICATION.DAYS_FIRST_DUE-DAYS_LAST_DUE)',
#  'MAX(PREVIOUS_APPLICATION.CNT_PAYMENT/DAYS_LAST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.DAYS_LAST_DUE_1ST_VERSION/DAYS_LAST_DUE)',
#  'MEDIAN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/DAYS_TERMINATION)',
#  'MIN(PREVIOUS_APPLICATION.CNT_PAYMENT/DAYS_TERMINATION)',
#  'MIN(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/DAYS_TERMINATION)',
#  'MAX(PREVIOUS_APPLICATION.DAYS_DECISION/DAYS_TERMINATION)',
#  'MIN(PREVIOUS_APPLICATION.AMT_ANNUITY/DAYS_TERMINATION)',
#  'MIN(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/DAYS_TERMINATION)',
#  'MIN(PREVIOUS_APPLICATION.AMT_APPLICATION/DAYS_TERMINATION)',
#  'MIN(PREVIOUS_APPLICATION.DAYS_LAST_DUE-DAYS_TERMINATION)',
#  'MEDIAN(PREVIOUS_APPLICATION.DAYS_LAST_DUE/DAYS_TERMINATION)',
#  'MIN(PREVIOUS_APPLICATION.DAYS_LAST_DUE_1ST_VERSION/DAYS_TERMINATION)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE*CREDIT_DAY_OVERDUE)',
#  'BUREAU.CREDIT_ACTIVE_Closed',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE*CNT_CREDIT_PROLONG)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_OVERDUE)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM)',
#  'MIN(BUREAU.CNT_CREDIT_PROLONG*DAYS_CREDIT)',
#  'MIN(BUREAU.CNT_CREDIT_PROLONG/DAYS_CREDIT)',
#  'MIN(BUREAU.DAYS_CREDIT/AMT_CREDIT_SUM)',
#  'MIN(BUREAU.DAYS_CREDIT*AMT_CREDIT_SUM)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_OVERDUE/DAYS_CREDIT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT/AMT_CREDIT_SUM)',
#  'MEAN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_OVERDUE)',
#  'MAX(BUREAU.CNT_CREDIT_PROLONG)',
#  'MAX(BUREAU.CREDIT_DAY_OVERDUE)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_OVERDUE)',
#  'MEAN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM)',
#  'MEAN(BUREAU.DAYS_CREDIT_UPDATE+DAYS_CREDIT)',
#  'MAX(BUREAU.COUNT(BUREAU_BALANCE))',
#  'MEDIAN(BUREAU.SUM(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MEDIAN(BUREAU.COUNT(BUREAU_BALANCE))',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_OVERDUE*CREDIT_DAY_OVERDUE)',
#  'MEAN(BUREAU.DAYS_CREDIT*AMT_CREDIT_SUM)',
#  'MAX(BUREAU.CNT_CREDIT_PROLONG*CREDIT_DAY_OVERDUE)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM)',
#  'MAX(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM)',
#  'MAX(BUREAU.CNT_CREDIT_PROLONG*AMT_CREDIT_SUM)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_OVERDUE*AMT_CREDIT_SUM)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_OVERDUE*CREDIT_DAY_OVERDUE)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_OVERDUE*CNT_CREDIT_PROLONG)',
#  'MEDIAN(BUREAU.DAYS_CREDIT)',
#  'MAX(BUREAU.DAYS_CREDIT_UPDATE+DAYS_CREDIT)',
#  'MAX(BUREAU.DAYS_CREDIT/AMT_CREDIT_SUM)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE/CREDIT_DAY_OVERDUE)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_UPDATE/CREDIT_DAY_OVERDUE)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM_OVERDUE)',
#  'MAX(BUREAU.DAYS_CREDIT_UPDATE/CREDIT_DAY_OVERDUE)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM_OVERDUE)',
#  'MAX(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM_OVERDUE)',
#  'MEAN(BUREAU.DAYS_CREDIT_UPDATE/CREDIT_DAY_OVERDUE)',
#  'MEAN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM_OVERDUE)',
#  'MEAN(BUREAU.CNT_CREDIT_PROLONG/AMT_CREDIT_SUM)',
#  'MIN(BUREAU.CREDIT_DAY_OVERDUE/AMT_CREDIT_SUM)',
#  'MAX(BUREAU.CREDIT_DAY_OVERDUE/AMT_CREDIT_SUM)',
#  'MAX(BUREAU.CNT_CREDIT_PROLONG/AMT_CREDIT_SUM)',
#  'MAX(BUREAU.CNT_CREDIT_PROLONG*DAYS_CREDIT_ENDDATE)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_OVERDUE-DAYS_CREDIT_ENDDATE)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_OVERDUE*DAYS_CREDIT_ENDDATE)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_OVERDUE-DAYS_CREDIT_ENDDATE)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_OVERDUE*DAYS_CREDIT_ENDDATE)',
#  'MIN(BUREAU.DAYS_CREDIT_ENDDATE)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_OVERDUE/DAYS_CREDIT_ENDDATE)',
#  'MAX(BUREAU.CREDIT_DAY_OVERDUE/DAYS_CREDIT_ENDDATE)',
#  'MEAN(BUREAU.CREDIT_DAY_OVERDUE/DAYS_CREDIT_ENDDATE)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_OVERDUE/DAYS_CREDIT_ENDDATE)',
#  'MAX(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_SUM_DEBT)',
#  'MAX(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM_DEBT)',
#  'MAX(BUREAU.CNT_CREDIT_PROLONG*AMT_CREDIT_SUM_DEBT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM+AMT_CREDIT_SUM_DEBT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_SUM_DEBT)',
#  'MIN(BUREAU.AMT_CREDIT_SUM+AMT_CREDIT_SUM_DEBT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_DEBT)',
#  'MEAN(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM_DEBT)',
#  'MIN(BUREAU.DAYS_CREDIT*AMT_CREDIT_SUM_DEBT)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_DEBT)',
#  'MEAN(BUREAU.DAYS_CREDIT/AMT_CREDIT_SUM_DEBT)',
#  'MEAN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM_DEBT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM/AMT_CREDIT_SUM_DEBT)',
#  'MIN(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT/DAYS_LAST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT*DAYS_LAST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT/DAYS_LAST_DUE)',
#  'MEAN(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT/DAYS_LAST_DUE)',
#  'MEAN(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT/DAYS_LAST_DUE)',
#  'MIN(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT/DAYS_TERMINATION)',
#  'MEDIAN(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT/DAYS_TERMINATION)',
#  'MEAN(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT/DAYS_TERMINATION)',
#  'MEAN(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT/DAYS_TERMINATION)',
#  'MIN(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT/DAYS_TERMINATION)',
#  'MAX(BUREAU.DAYS_CREDIT_ENDDATE*AMT_CREDIT_SUM_DEBT)',
#  'STD(PREVIOUS_APPLICATION.AMT_APPLICATION*AMT_CREDIT)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA/DAYS_DECISION)',
#  'STD(PREVIOUS_APPLICATION.AMT_APPLICATION/DAYS_DECISION)',
#  'STD(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/DAYS_DECISION)',
#  'STD(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY)',
#  'STD(PREVIOUS_APPLICATION.AMT_APPLICATION)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA)',
#  'STD(PREVIOUS_APPLICATION.AMT_APPLICATION*DAYS_DECISION)',
#  'STD(PREVIOUS_APPLICATION.AMT_APPLICATION/HOUR_APPR_PROCESS_START)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_DEBT*AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.DAYS_CREDIT/AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.DAYS_CREDIT*AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.CNT_CREDIT_PROLONG*AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.DAYS_CREDIT/AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT/AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_DEBT*AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.DAYS_CREDIT*AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_DEBT*AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.DAYS_CREDIT*AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_DEBT*AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT*AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.DAYS_CREDIT/AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM/AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM/AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.AMT_CREDIT_SUM/AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM/AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_ENDDATE*AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.DAYS_CREDIT_ENDDATE*AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.DAYS_CREDIT_ENDDATE*AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.DAYS_CREDIT_ENDDATE*AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.DAYS_CREDIT_ENDDATE/AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.DAYS_CREDIT_ENDDATE/AMT_CREDIT_SUM_LIMIT)',
#  'STD(PREVIOUS_APPLICATION.CNT_PAYMENT*AMT_ANNUITY)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA-AMT_ANNUITY)',
#  'STD(PREVIOUS_APPLICATION.AMT_APPLICATION*AMT_ANNUITY)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA+AMT_ANNUITY)',
#  'STD(PREVIOUS_APPLICATION.AMT_APPLICATION-AMT_GOODS_PRICE)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA/AMT_ANNUITY)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE*AMT_CREDIT_SUM)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE+DAYS_CREDIT)',
#  'STD(BUREAU.CREDIT_DAY_OVERDUE/DAYS_CREDIT)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE*CNT_CREDIT_PROLONG)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE*CREDIT_DAY_OVERDUE)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE/DAYS_CREDIT)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE-DAYS_CREDIT)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE*CNT_CREDIT_PROLONG)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG*CREDIT_DAY_OVERDUE)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG*DAYS_CREDIT)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG/DAYS_CREDIT)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG*AMT_CREDIT_SUM)',
#  'STD(BUREAU.DAYS_CREDIT*AMT_CREDIT_SUM)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE*CREDIT_DAY_OVERDUE)',
#  'STD(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_OVERDUE)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE)',
#  'STD(BUREAU.SUM(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'STD(BUREAU.AMT_CREDIT_SUM)',
#  'STD(BUREAU.DAYS_CREDIT)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE)',
#  'STD(BUREAU.CREDIT_DAY_OVERDUE)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE/DAYS_CREDIT)',
#  'MEAN(BUREAU.DAYS_ENDDATE_FACT)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM/DAYS_ENDDATE_FACT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM/DAYS_ENDDATE_FACT)',
#  'MAX(BUREAU.DAYS_ENDDATE_FACT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT-DAYS_ENDDATE_FACT)',
#  'MAX(BUREAU.DAYS_CREDIT-DAYS_ENDDATE_FACT)',
#  'MEDIAN(BUREAU.DAYS_ENDDATE_FACT)',
#  'MAX(BUREAU.DAYS_CREDIT_UPDATE-DAYS_ENDDATE_FACT)',
#  'MAX(BUREAU.DAYS_CREDIT/DAYS_ENDDATE_FACT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM/DAYS_ENDDATE_FACT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT/DAYS_ENDDATE_FACT)',
#  'MIN(BUREAU.AMT_CREDIT_SUM/DAYS_ENDDATE_FACT)',
#  'MEAN(BUREAU.DAYS_CREDIT/DAYS_ENDDATE_FACT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_UPDATE-DAYS_ENDDATE_FACT)',
#  'MIN(BUREAU.DAYS_CREDIT-DAYS_ENDDATE_FACT)',
#  'MIN(BUREAU.DAYS_CREDIT/DAYS_ENDDATE_FACT)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE-DAYS_ENDDATE_FACT)',
#  'MEAN(BUREAU.DAYS_CREDIT_UPDATE-DAYS_ENDDATE_FACT)',
#  'MEAN(BUREAU.DAYS_CREDIT-DAYS_ENDDATE_FACT)',
#  'MIN(BUREAU.DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE/AMT_CREDIT_SUM)',
#  'STD(BUREAU.CREDIT_DAY_OVERDUE/AMT_CREDIT_SUM)',
#  'MEAN(BUREAU.DAYS_CREDIT_ENDDATE*DAYS_ENDDATE_FACT)',
#  'MEAN(BUREAU.DAYS_CREDIT_ENDDATE/DAYS_ENDDATE_FACT)',
#  'MAX(BUREAU.DAYS_CREDIT_ENDDATE/DAYS_ENDDATE_FACT)',
#  'MAX(BUREAU.DAYS_CREDIT_ENDDATE*DAYS_ENDDATE_FACT)',
#  'MIN(BUREAU.DAYS_CREDIT_ENDDATE*DAYS_ENDDATE_FACT)',
#  'MIN(BUREAU.DAYS_CREDIT_ENDDATE/DAYS_ENDDATE_FACT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_ENDDATE*DAYS_ENDDATE_FACT)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_ENDDATE/DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG/AMT_CREDIT_SUM)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE+DAYS_CREDIT_ENDDATE)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE-DAYS_CREDIT_ENDDATE)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE*DAYS_CREDIT_ENDDATE)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG*DAYS_CREDIT_ENDDATE)',
#  'STD(BUREAU.CREDIT_DAY_OVERDUE*DAYS_CREDIT_ENDDATE)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE/DAYS_CREDIT_ENDDATE)',
#  'STD(BUREAU.CREDIT_DAY_OVERDUE/DAYS_CREDIT_ENDDATE)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_DEBT*DAYS_ENDDATE_FACT)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_DEBT*DAYS_ENDDATE_FACT)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_DEBT*DAYS_ENDDATE_FACT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_DEBT*DAYS_ENDDATE_FACT)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_DEBT/DAYS_ENDDATE_FACT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_DEBT/DAYS_ENDDATE_FACT)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_DEBT/DAYS_ENDDATE_FACT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_DEBT/DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM_DEBT)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG*AMT_CREDIT_SUM_DEBT)',
#  'STD(BUREAU.AMT_CREDIT_SUM_DEBT)',
#  'STD(BUREAU.DAYS_CREDIT*AMT_CREDIT_SUM_DEBT)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_DEBT)',
#  'STD(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_SUM_DEBT)',
#  'STD(BUREAU.AMT_CREDIT_SUM+AMT_CREDIT_SUM_DEBT)',
#  'STD(PREVIOUS_APPLICATION.AMT_ANNUITY*NFLAG_INSURED_ON_APPROVAL)',
#  'STD(PREVIOUS_APPLICATION.AMT_APPLICATION*NFLAG_INSURED_ON_APPROVAL)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA*NFLAG_INSURED_ON_APPROVAL)',
#  'STD(BUREAU.DAYS_CREDIT_ENDDATE*AMT_CREDIT_SUM_DEBT)',
#  'MAX(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/AMT_DOWN_PAYMENT)',
#  'MAX(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/RATE_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/AMT_DOWN_PAYMENT)',
#  'MEDIAN(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/RATE_DOWN_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/RATE_DOWN_PAYMENT)',
#  'MIN(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/AMT_DOWN_PAYMENT)',
#  'MEAN(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/AMT_DOWN_PAYMENT)',
#  'STD(PREVIOUS_APPLICATION.DAYS_DECISION/DAYS_FIRST_DUE)',
#  'STD(PREVIOUS_APPLICATION.CNT_PAYMENT/DAYS_FIRST_DUE)',
#  'STD(PREVIOUS_APPLICATION.AMT_ANNUITY/DAYS_FIRST_DUE)',
#  'STD(PREVIOUS_APPLICATION.AMT_APPLICATION/DAYS_FIRST_DUE)',
#  'STD(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/DAYS_FIRST_DUE)',
#  'STD(PREVIOUS_APPLICATION.DAYS_DECISION-DAYS_FIRST_DUE)',
#  'STD(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/DAYS_FIRST_DUE)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA/DAYS_FIRST_DUE)',
#  'MIN(BUREAU.CNT_CREDIT_PROLONG/AMT_CREDIT_SUM_DEBT)',
#  'MAX(BUREAU.CNT_CREDIT_PROLONG/AMT_CREDIT_SUM_DEBT)',
#  'MEAN(BUREAU.CREDIT_DAY_OVERDUE/AMT_CREDIT_SUM_DEBT)',
#  'MAX(BUREAU.CREDIT_DAY_OVERDUE/AMT_CREDIT_SUM_DEBT)',
#  'MEDIAN(BUREAU.CREDIT_DAY_OVERDUE/AMT_CREDIT_SUM_DEBT)',
#  'MIN(BUREAU.CREDIT_DAY_OVERDUE/AMT_CREDIT_SUM_DEBT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_OVERDUE/AMT_CREDIT_SUM_DEBT)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_OVERDUE/AMT_CREDIT_SUM_DEBT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_OVERDUE/AMT_CREDIT_SUM_DEBT)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_LIMIT/DAYS_ENDDATE_FACT)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA*DAYS_LAST_DUE_1ST_VERSION)',
#  'STD(BUREAU.DAYS_CREDIT*AMT_CREDIT_SUM_LIMIT)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG*AMT_CREDIT_SUM_LIMIT)',
#  'STD(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'STD(BUREAU.AMT_CREDIT_SUM_LIMIT)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_LIMIT)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'STD(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_SUM_LIMIT)',
#  'SKEW(BUREAU.AMT_CREDIT_SUM_OVERDUE*CREDIT_DAY_OVERDUE)',
#  'SKEW(BUREAU.AMT_CREDIT_SUM_OVERDUE*AMT_CREDIT_SUM)',
#  'SKEW(BUREAU.CNT_CREDIT_PROLONG*CREDIT_DAY_OVERDUE)',
#  'SKEW(BUREAU.CNT_CREDIT_PROLONG*DAYS_CREDIT)',
#  'SKEW(BUREAU.CREDIT_DAY_OVERDUE*AMT_CREDIT_SUM)',
#  'SKEW(BUREAU.CNT_CREDIT_PROLONG/DAYS_CREDIT)',
#  'SKEW(BUREAU.CREDIT_DAY_OVERDUE/DAYS_CREDIT)',
#  'SKEW(BUREAU.AMT_CREDIT_SUM_OVERDUE/DAYS_CREDIT)',
#  'SKEW(BUREAU.CNT_CREDIT_PROLONG)',
#  'SKEW(BUREAU.AMT_CREDIT_SUM_OVERDUE)',
#  'SKEW(BUREAU.CREDIT_DAY_OVERDUE)',
#  'SKEW(BUREAU.AMT_CREDIT_SUM_OVERDUE/AMT_CREDIT_SUM)',
#  'MAX(BUREAU.CNT_CREDIT_PROLONG*AMT_CREDIT_MAX_OVERDUE)',
#  'MEAN(BUREAU.AMT_CREDIT_MAX_OVERDUE)',
#  'MAX(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_MAX_OVERDUE)',
#  'MEAN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_MAX_OVERDUE)',
#  'MAX(BUREAU.AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.AMT_CREDIT_MAX_OVERDUE)',
#  'MAX(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_MAX_OVERDUE)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.CNT_CREDIT_PROLONG*AMT_CREDIT_MAX_OVERDUE)',
#  'MIN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_MAX_OVERDUE)',
#  'STD(BUREAU.DAYS_CREDIT_ENDDATE*AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.DAYS_CREDIT_ENDDATE/AMT_CREDIT_SUM_DEBT)',
#  'STD(BUREAU.DAYS_CREDIT/AMT_CREDIT_SUM)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE/AMT_CREDIT_SUM)',
#  'MAX(BUREAU.AMT_CREDIT_SUM/AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM/AMT_CREDIT_MAX_OVERDUE)',
#  'MIN(BUREAU.AMT_CREDIT_SUM/AMT_CREDIT_MAX_OVERDUE)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM/AMT_CREDIT_MAX_OVERDUE)',
#  'SKEW(BUREAU.AMT_CREDIT_SUM_OVERDUE+DAYS_CREDIT_ENDDATE)',
#  'SKEW(BUREAU.DAYS_CREDIT_ENDDATE)',
#  'SKEW(BUREAU.CNT_CREDIT_PROLONG/DAYS_CREDIT_ENDDATE)',
#  'SKEW(BUREAU.CREDIT_DAY_OVERDUE/DAYS_CREDIT_ENDDATE)',
#  'SKEW(BUREAU.AMT_CREDIT_SUM_OVERDUE/DAYS_CREDIT_ENDDATE)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_DEBT/AMT_CREDIT_SUM_LIMIT)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_DEBT/AMT_CREDIT_SUM_LIMIT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_DEBT/AMT_CREDIT_SUM_LIMIT)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_DEBT/AMT_CREDIT_SUM_LIMIT)',
#  'MIN(BUREAU.DAYS_CREDIT_ENDDATE*AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_ENDDATE*AMT_CREDIT_MAX_OVERDUE)',
#  'MEAN(BUREAU.DAYS_CREDIT_ENDDATE*AMT_CREDIT_MAX_OVERDUE)',
#  'MAX(BUREAU.DAYS_CREDIT_ENDDATE/AMT_CREDIT_MAX_OVERDUE)',
#  'MIN(BUREAU.DAYS_CREDIT_ENDDATE/AMT_CREDIT_MAX_OVERDUE)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_DEBT*AMT_CREDIT_MAX_OVERDUE)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_DEBT*AMT_CREDIT_MAX_OVERDUE)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_DEBT*AMT_CREDIT_MAX_OVERDUE)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_LIMIT+AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_LIMIT-AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_LIMIT+AMT_CREDIT_MAX_OVERDUE)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_LIMIT-AMT_CREDIT_MAX_OVERDUE)',
#  'SKEW(PREVIOUS_APPLICATION.SELLERPLACE_AREA+AMT_ANNUITY)',
#  'SKEW(PREVIOUS_APPLICATION.SELLERPLACE_AREA-AMT_ANNUITY)',
#  'SKEW(PREVIOUS_APPLICATION.AMT_APPLICATION/AMT_GOODS_PRICE)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE-DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.DAYS_CREDIT-DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.DAYS_CREDIT/DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.AMT_CREDIT_SUM/DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.DAYS_CREDIT_ENDDATE*DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.DAYS_CREDIT_ENDDATE/DAYS_ENDDATE_FACT)',
#  'STD(PREVIOUS_APPLICATION.DAYS_FIRST_DUE/DAYS_LAST_DUE)',
#  'STD(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/DAYS_LAST_DUE)',
#  'STD(PREVIOUS_APPLICATION.AMT_CREDIT/DAYS_LAST_DUE)',
#  'STD(PREVIOUS_APPLICATION.CNT_PAYMENT/DAYS_LAST_DUE)',
#  'STD(PREVIOUS_APPLICATION.NFLAG_LAST_APPL_IN_DAY/DAYS_LAST_DUE)',
#  'STD(PREVIOUS_APPLICATION.AMT_ANNUITY/DAYS_LAST_DUE)',
#  'MEDIAN(BUREAU.DAYS_CREDIT_ENDDATE/AMT_CREDIT_MAX_OVERDUE)',
#  'STD(PREVIOUS_APPLICATION.DAYS_DECISION*AMT_DOWN_PAYMENT)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA*AMT_DOWN_PAYMENT)',
#  'STD(PREVIOUS_APPLICATION.AMT_CREDIT*AMT_DOWN_PAYMENT)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA*RATE_DOWN_PAYMENT)',
#  'STD(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA-AMT_DOWN_PAYMENT)',
#  'STD(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START/DAYS_TERMINATION)',
#  'STD(PREVIOUS_APPLICATION.AMT_APPLICATION/DAYS_TERMINATION)',
#  'STD(PREVIOUS_APPLICATION.AMT_ANNUITY/DAYS_TERMINATION)',
#  'STD(PREVIOUS_APPLICATION.DAYS_DECISION/DAYS_TERMINATION)',
#  'STD(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/DAYS_TERMINATION)',
#  'STD(PREVIOUS_APPLICATION.CNT_PAYMENT/DAYS_TERMINATION)',
#  'STD(PREVIOUS_APPLICATION.DAYS_LAST_DUE-DAYS_TERMINATION)',
#  'STD(PREVIOUS_APPLICATION.DAYS_LAST_DUE/DAYS_TERMINATION)',
#  'STD(PREVIOUS_APPLICATION.DAYS_LAST_DUE_1ST_VERSION/DAYS_LAST_DUE)',
#  'STD(PREVIOUS_APPLICATION.DAYS_LAST_DUE_1ST_VERSION/DAYS_TERMINATION)',
#  'STD(PREVIOUS_APPLICATION.AMT_ANNUITY-AMT_DOWN_PAYMENT)',
#  'STD(BUREAU.AMT_CREDIT_SUM_DEBT*DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.AMT_CREDIT_SUM_DEBT/DAYS_ENDDATE_FACT)',
#  'YEARS_BEGINEXPLUATATION_AVG',
#  'YEARS_BEGINEXPLUATATION_MODE',
#  'FLOORSMAX_MODE',
#  'FLOORSMAX_AVG',
#  'LIVINGAREA_MODE',
#  'LIVINGAREA_AVG',
#  'ENTRANCES_MEDI',
#  'ENTRANCES_AVG',
#  'SKEW(BUREAU.AMT_CREDIT_SUM_OVERDUE*AMT_CREDIT_SUM_LIMIT)',
#  'SKEW(BUREAU.AMT_CREDIT_SUM_LIMIT)',
#  'SKEW(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_SUM_LIMIT)',
#  'SKEW(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_SUM_LIMIT)',
#  'APARTMENTS_MODE',
#  'APARTMENTS_MEDI',
#  'STD(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL*RATE_DOWN_PAYMENT)',
#  'STD(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL*AMT_DOWN_PAYMENT)',
#  'STD(PREVIOUS_APPLICATION.DAYS_LAST_DUE_1ST_VERSION*AMT_DOWN_PAYMENT)',
#  'ELEVATORS_MEDI',
#  'ELEVATORS_AVG',
#  'SKEW(PREVIOUS_APPLICATION.HOUR_APPR_PROCESS_START*NFLAG_INSURED_ON_APPROVAL)',
#  'NONLIVINGAREA_MODE',
#  'NONLIVINGAREA_AVG',
#  'STD(BUREAU.AMT_CREDIT_SUM_LIMIT/DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.AMT_CREDIT_SUM_LIMIT*DAYS_ENDDATE_FACT)',
#  'STD(PREVIOUS_APPLICATION.SELLERPLACE_AREA/AMT_CREDIT)',
#  'MEAN(BUREAU.DAYS_CREDIT_ENDDATE/AMT_CREDIT_MAX_OVERDUE)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_DEBT/AMT_CREDIT_MAX_OVERDUE)',
#  'MIN(BUREAU.AMT_CREDIT_SUM_DEBT/AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_DEBT/AMT_CREDIT_MAX_OVERDUE)',
#  'BASEMENTAREA_AVG',
#  'BASEMENTAREA_MEDI',
#  'LANDAREA_AVG',
#  'LANDAREA_MEDI',
#  'STD(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT/DAYS_LAST_DUE)',
#  'STD(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT/DAYS_LAST_DUE)',
#  'STD(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT*DAYS_LAST_DUE)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_DEBT/AMT_CREDIT_MAX_OVERDUE)',
#  'STD(PREVIOUS_APPLICATION.RATE_DOWN_PAYMENT/DAYS_TERMINATION)',
#  'STD(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT/DAYS_TERMINATION)',
#  'STD(BUREAU.AMT_CREDIT_SUM*AMT_CREDIT_MAX_OVERDUE)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG*AMT_CREDIT_MAX_OVERDUE)',
#  'STD(BUREAU.AMT_CREDIT_MAX_OVERDUE)',
#  'STD(BUREAU.DAYS_CREDIT_UPDATE*AMT_CREDIT_MAX_OVERDUE)',
#  'STD(BUREAU.CREDIT_DAY_OVERDUE/AMT_CREDIT_SUM_DEBT)',
#  'STD(BUREAU.AMT_CREDIT_SUM_OVERDUE/AMT_CREDIT_SUM_DEBT)',
#  'STD(BUREAU.CNT_CREDIT_PROLONG/AMT_CREDIT_SUM_DEBT)',
#  'MEAN(BUREAU.DAYS_CREDIT_ENDDATE/AMT_CREDIT_SUM_LIMIT)',
#  'SKEW(BUREAU.AMT_CREDIT_SUM_DEBT/DAYS_ENDDATE_FACT)',
#  'STD(BUREAU.AMT_CREDIT_SUM_DEBT*AMT_CREDIT_MAX_OVERDUE)',
#  'STD(BUREAU.AMT_CREDIT_SUM_LIMIT-AMT_CREDIT_MAX_OVERDUE)',
#  'STD(BUREAU.AMT_CREDIT_SUM_LIMIT+AMT_CREDIT_MAX_OVERDUE)',
#  'YEARS_BUILD_AVG',
#  'YEARS_BUILD_MEDI',
#  'FLOORSMIN_AVG',
#  'FLOORSMIN_MEDI',
#  'MEAN(BUREAU.BUREAU_BALANCE.STATUS_5)',
#  'MIN(BUREAU_BALANCE.MONTHS_BALANCE)',
#  'MIN(BUREAU.MEAN(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MEAN(BUREAU.MIN(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MEDIAN(BUREAU.MEDIAN(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MEDIAN(BUREAU.MIN(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MEDIAN(BUREAU_BALANCE.MONTHS_BALANCE)',
#  'MAX(BUREAU.MEDIAN(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MAX(BUREAU.MEAN(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MAX(BUREAU.MIN(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MEAN(BUREAU.MEAN(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MEDIAN(BUREAU.STD(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MIN(BUREAU.STD(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MEAN(BUREAU.STD(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'MAX(BUREAU.STD(BUREAU_BALANCE.MONTHS_BALANCE))',
#  'LIVINGAPARTMENTS_MEDI',
#  'LIVINGAPARTMENTS_AVG',
#  'SKEW(PREVIOUS_APPLICATION.NFLAG_INSURED_ON_APPROVAL/DAYS_TERMINATION)',
#  'SKEW(PREVIOUS_APPLICATION.CNT_PAYMENT/DAYS_TERMINATION)',
#  'SKEW(PREVIOUS_APPLICATION.AMT_DOWN_PAYMENT)',
#  'SKEW(PREVIOUS_APPLICATION.AMT_GOODS_PRICE*AMT_DOWN_PAYMENT)',
#  'MAX(BUREAU.AMT_CREDIT_SUM_LIMIT/AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(BUREAU.AMT_CREDIT_SUM_LIMIT/AMT_CREDIT_MAX_OVERDUE)',
#  'MEAN(BUREAU.AMT_CREDIT_SUM_LIMIT/AMT_CREDIT_MAX_OVERDUE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*CNT_DRAWINGS_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_PAYMENT_TOTAL_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_DRAWINGS_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_INST_MIN_REGULARITY)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*MONTHS_BALANCE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*CNT_DRAWINGS_CURRENT)',
#  'CREDIT_CARD_BALANCE.NAME_CONTRACT_STATUS_Demand',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT/MONTHS_BALANCE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'MEDIAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE*AMT_INST_MIN_REGULARITY)',
#  'MEDIAN(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'MEDIAN(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT/MONTHS_BALANCE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*MONTHS_BALANCE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/MONTHS_BALANCE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*MONTHS_BALANCE)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD_DEF+MONTHS_BALANCE)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD_DEF-MONTHS_BALANCE)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD_DEF*AMT_INST_MIN_REGULARITY)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD_DEF+CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*SK_DPD)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD_DEF-CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE*CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.SK_DPD_DEF+MONTHS_BALANCE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.SK_DPD_DEF*MONTHS_BALANCE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.SK_DPD_DEF*AMT_PAYMENT_TOTAL_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.SK_DPD_DEF*AMT_TOTAL_RECEIVABLE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY)',
#  'MEDIAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.SK_DPD)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.SK_DPD_DEF)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY*CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE-CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.SK_DPD_DEF-MONTHS_BALANCE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.SK_DPD_DEF+CNT_INSTALMENT_MATURE_CUM)',
#  'MIN(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'MIN(CREDIT_CARD_BALANCE.MONTHS_BALANCE/AMT_INST_MIN_REGULARITY)',
#  'MIN(CREDIT_CARD_BALANCE.MONTHS_BALANCE*CNT_INSTALMENT_MATURE_CUM)',
#  'MIN(CREDIT_CARD_BALANCE.MONTHS_BALANCE/CNT_INSTALMENT_MATURE_CUM)',
#  'MIN(CREDIT_CARD_BALANCE.MONTHS_BALANCE+CNT_INSTALMENT_MATURE_CUM)',
#  'MIN(CREDIT_CARD_BALANCE.MONTHS_BALANCE-CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.SK_DPD_DEF-CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*CNT_DRAWINGS_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE-AMT_RECEIVABLE_PRINCIPAL)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE-AMT_RECIVABLE)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*AMT_PAYMENT_TOTAL_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*AMT_DRAWINGS_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*AMT_BALANCE)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT-AMT_PAYMENT_TOTAL_CURRENT)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*SK_DPD)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*SK_DPD)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD*CNT_DRAWINGS_CURRENT)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD*CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*AMT_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE*CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_BALANCE-AMT_RECEIVABLE_PRINCIPAL)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_DRAWINGS_CURRENT)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_PAYMENT_TOTAL_CURRENT)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*AMT_PAYMENT_TOTAL_CURRENT)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*AMT_DRAWINGS_CURRENT)',
#  'MAX(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'MEDIAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE+CNT_INSTALMENT_MATURE_CUM)',
#  'MIN(CREDIT_CARD_BALANCE.MONTHS_BALANCE)',
#  'MAX(CREDIT_CARD_BALANCE.CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD_DEF*AMT_TOTAL_RECEIVABLE)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD_DEF*AMT_DRAWINGS_CURRENT)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD_DEF*AMT_PAYMENT_TOTAL_CURRENT)',
#  'MIN(CREDIT_CARD_BALANCE.SK_DPD_DEF*MONTHS_BALANCE)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD_DEF*CNT_DRAWINGS_CURRENT)',
#  'MIN(CREDIT_CARD_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'MIN(CREDIT_CARD_BALANCE.SK_DPD_DEF+MONTHS_BALANCE)',
#  'MIN(CREDIT_CARD_BALANCE.SK_DPD_DEF+CNT_INSTALMENT_MATURE_CUM)',
#  'MIN(CREDIT_CARD_BALANCE.SK_DPD_DEF-CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY*CNT_INSTALMENT_MATURE_CUM)',
#  'MEDIAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE-CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.SK_ID_PREV)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD_DEF)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT)',
#  'MAX(CREDIT_CARD_BALANCE.SK_DPD)',
#  'MAX(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.MONTHS_BALANCE+CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.MONTHS_BALANCE-CNT_INSTALMENT_MATURE_CUM)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY*CNT_INSTALMENT_MATURE_CUM)',
#  'MIN(CREDIT_CARD_BALANCE.SK_ID_PREV)',
#  'MEAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE/CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD_DEF*MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD_DEF-CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD)',
#  'MEAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY)',
#  'MEAN(CREDIT_CARD_BALANCE.CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD_DEF*AMT_TOTAL_RECEIVABLE)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD_DEF*AMT_PAYMENT_TOTAL_CURRENT)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD_DEF+MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD_DEF-MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD_DEF+CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*AMT_BALANCE)',
#  'MIN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT/MONTHS_BALANCE)',
#  'MIN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE+AMT_CREDIT_LIMIT_ACTUAL)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*AMT_DRAWINGS_CURRENT)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*AMT_PAYMENT_TOTAL_CURRENT)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE-AMT_RECIVABLE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE*CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE/AMT_INST_MIN_REGULARITY)',
#  'MIN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE+AMT_CREDIT_LIMIT_ACTUAL)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_ID_PREV)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD_DEF)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_TOTAL_RECEIVABLE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT)',
#  'MIN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*MONTHS_BALANCE)',
#  'MIN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*MONTHS_BALANCE)',
#  'MIN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*AMT_PAYMENT_TOTAL_CURRENT)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_PAYMENT_TOTAL_CURRENT)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*SK_DPD)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT/MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_INST_MIN_REGULARITY)',
#  'MIN(CREDIT_CARD_BALANCE.SK_DPD/MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*SK_DPD)',
#  'MEAN(CREDIT_CARD_BALANCE.MONTHS_BALANCE*AMT_INST_MIN_REGULARITY)',
#  'MEAN(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_BALANCE-AMT_RECEIVABLE_PRINCIPAL)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_DRAWINGS_CURRENT)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT+AMT_PAYMENT_TOTAL_CURRENT)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD*CNT_INSTALMENT_MATURE_CUM)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD/MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.SK_DPD*MONTHS_BALANCE)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*SK_DPD)',
#  'MIN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/AMT_DRAWINGS_CURRENT)',
#  'MAX(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/AMT_DRAWINGS_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/AMT_DRAWINGS_CURRENT)',
#  'MEAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/AMT_DRAWINGS_CURRENT)',
#  'MIN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/AMT_PAYMENT_TOTAL_CURRENT)',
#  'MEDIAN(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/CNT_DRAWINGS_CURRENT)',
#  'NONLIVINGAPARTMENTS_AVG',
#  'NONLIVINGAPARTMENTS_MEDI',
#  'STD(CREDIT_CARD_BALANCE.CNT_INSTALMENT_MATURE_CUM)',
#  'STD(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT)',
#  'STD(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT)',
#  'STD(CREDIT_CARD_BALANCE.SK_DPD)',
#  'STD(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT)',
#  'STD(CREDIT_CARD_BALANCE.MONTHS_BALANCE)',
#  'STD(CREDIT_CARD_BALANCE.SK_DPD_DEF)',
#  'STD(CREDIT_CARD_BALANCE.SK_DPD/MONTHS_BALANCE)',
#  'STD(CREDIT_CARD_BALANCE.MONTHS_BALANCE+CNT_INSTALMENT_MATURE_CUM)',
#  'STD(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'STD(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'STD(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY*CNT_INSTALMENT_MATURE_CUM)',
#  'STD(CREDIT_CARD_BALANCE.CNT_DRAWINGS_CURRENT/MONTHS_BALANCE)',
#  'STD(CREDIT_CARD_BALANCE.MONTHS_BALANCE*CNT_INSTALMENT_MATURE_CUM)',
#  'STD(CREDIT_CARD_BALANCE.SK_DPD*CNT_INSTALMENT_MATURE_CUM)',
#  'STD(CREDIT_CARD_BALANCE.AMT_INST_MIN_REGULARITY)',
#  'STD(CREDIT_CARD_BALANCE.SK_DPD_DEF/MONTHS_BALANCE)',
#  'STD(CREDIT_CARD_BALANCE.SK_DPD_DEF*AMT_TOTAL_RECEIVABLE)',
#  'STD(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*MONTHS_BALANCE)',
#  'STD(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*CNT_DRAWINGS_CURRENT)',
#  'STD(CREDIT_CARD_BALANCE.SK_DPD_DEF*AMT_DRAWINGS_CURRENT)',
#  'STD(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL/MONTHS_BALANCE)',
#  'STD(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_INST_MIN_REGULARITY)',
#  'STD(CREDIT_CARD_BALANCE.SK_DPD*MONTHS_BALANCE)',
#  'STD(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'STD(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'STD(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*CNT_INSTALMENT_MATURE_CUM)',
#  'STD(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT/MONTHS_BALANCE)',
#  'STD(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*AMT_PAYMENT_TOTAL_CURRENT)',
#  'STD(CREDIT_CARD_BALANCE.AMT_CREDIT_LIMIT_ACTUAL*AMT_PAYMENT_TOTAL_CURRENT)',
#  'STD(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*CNT_DRAWINGS_CURRENT)',
#  'STD(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*SK_DPD)',
#  'STD(CREDIT_CARD_BALANCE.AMT_PAYMENT_TOTAL_CURRENT*SK_DPD)',
#  'STD(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*CNT_INSTALMENT_MATURE_CUM)',
#  'STD(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*CNT_DRAWINGS_CURRENT)',
#  'STD(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*MONTHS_BALANCE)',
#  'STD(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT*AMT_INST_MIN_REGULARITY)',
#  'STD(CREDIT_CARD_BALANCE.AMT_DRAWINGS_CURRENT/MONTHS_BALANCE)',
#  ...]

# %%
X.drop(to_drop,axis=1,inplace=True)

# %% [markdown]
# ## Drop all zero importance features, identified by running a base light GBM model twice

# %%
def identify_zero_importance_features(train, train_labels, iterations = 2):

    
    # Initialize an empty array to hold feature importances
    feature_importances = np.zeros(train.shape[1])

    # Create the model with several hyperparameters
    model = lgb.LGBMClassifier(objective='binary', boosting_type = 'goss', 
                               n_estimators = 10000, class_weight = 'balanced')
    
    # Fit the model multiple times to avoid overfitting
    for i in range(iterations):

        # Split into training and validation set
        train_features, valid_features, train_y, valid_y = train_test_split(train, train_labels, 
                                                                            test_size = 0.25, 
                                                                            random_state = i)

        # Train using early stopping
        model.fit(train_features, train_y, early_stopping_rounds=100, 
                  eval_set = [(valid_features, valid_y)], 
                  eval_metric = 'auc', verbose = 200)

        # Record the feature importances
        feature_importances += model.feature_importances_ / iterations
    
    feature_importances = pd.DataFrame({'feature': list(train.columns), 
                            'importance': feature_importances}).sort_values('importance', 
                                                                            ascending = False)
    
    # Find the features with zero importance
    zero_features = list(feature_importances[feature_importances['importance'] == 0.0]['feature'])
    print('\nThere are %d features with 0.0 importance' % len(zero_features))
    
    return zero_features

zero_features=identify_zero_importance_features(X, Y, iterations = 3)
# Out:
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [55]	valid_0's auc: 0.765211	valid_0's binary_logloss: 0.578987
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [70]	valid_0's auc: 0.769223	valid_0's binary_logloss: 0.576006
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [59]	valid_0's auc: 0.768828	valid_0's binary_logloss: 0.575613
#
# There are 1278 features with 0.0 importance

# %%
X.drop(zero_features,axis=1,inplace=True)

# %%
X.to_pickle('loan data_1327.pkl')
